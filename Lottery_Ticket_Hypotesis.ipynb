# %%
#! pip install -q tensorflow-model-optimization
#! pip install tensorflow-addons

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from LTH_helper import LTH

# %% [markdown]
# https://arxiv.org/abs/1803.03635
#
# https://www.youtube.com/watch?v=0VH1Lim8gL8&feature=youtu.be&t=2760

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
import os
import random as rn
from matplotlib import pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import ReduceLROnPlateau, ModelCheckpoint
import tensorflow_model_optimization as tfmot
from tensorflow.keras import initializers

# %%
def set_random_seeds(seed=42):
    os.environ['PYTHONHASHSEED'] = '0'
    np.random.seed(seed)
    rn.seed(seed)
    tf.random.set_seed(seed)
    # session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
    # sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
    # K.set_session(sess)

# %% [markdown]
# # Cargo datos

# %%
folder = './'

# %%
X = np.load(folder+'train_images.npy').reshape(-1, 784)/255
y = np.loadtxt(folder+'train_labels.csv', delimiter=',', skiprows=1).reshape(-1, 1)
X_test = np.load(folder+'test_images.npy').reshape(-1, 784)/255
y_test = pd.read_csv(folder+'test_labels.csv')['Category'].values

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=42)

# %% [markdown]
# # Red neuronal básica

# %%
def compile_model(model, lr=0.001):
    optim = optimizers.Adam(lr=lr)
    model.compile(loss = 'sparse_categorical_crossentropy', optimizer=optim, metrics=['accuracy'])

# %%
def get_model(compile_model_flag=True, lr=0.001):
    reduce = 2
    input_dim=784
    output_size = 10
    # Creo el modelo
    model = Sequential()
    model.add(Dense(784*2//reduce, activation='linear', name='hidden_1', kernel_initializer=initializers.glorot_uniform(),
                    input_dim=input_dim))
    #model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(784//reduce, activation='linear', name='hidden_2', kernel_initializer=initializers.glorot_uniform(),
                   ))
    #model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dense(output_size, name='Salida', kernel_initializer=initializers.glorot_uniform(),
                   ))
    model.add(Activation('softmax'))
    if compile_model_flag:
        compile_model(model, lr=lr)
    return model
model = get_model()
# model.save_weights('random-init.hdf5')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# hidden_1 (Dense)             (None, 784)               615440
# _________________________________________________________________
# activation (Activation)      (None, 784)               0
# _________________________________________________________________
# hidden_2 (Dense)             (None, 392)               307720
# _________________________________________________________________
# activation_1 (Activation)    (None, 392)               0
# _________________________________________________________________
# Salida (Dense)               (None, 10)                3930
# _________________________________________________________________
# activation_2 (Activation)    (None, 10)                0
# =================================================================
# Total params: 927,090
# Trainable params: 927,090
# Non-trainable params: 0
# _________________________________________________________________

# %%
lth = LTH(get_model)

# %% [markdown]
# ![LTH_alg.png](LTH_alg.png)

# %% [markdown]
# # Step 1 and 2. Initialize and Train network

# %%
def get_callbacks(filename):
    return [
        ReduceLROnPlateau(monitor='val_accuracy', mode='max', factor=np.sqrt(0.1), patience=10, verbose=1, min_lr=1e-4),
        ModelCheckpoint(filepath=filename,  verbose=1, save_best_only=True, monitor='val_accuracy', mode='max')
    ]

# %%
batch_size = 256
epochs = 100

# %%
# Step 1 
model = get_model()
# Save initial weights
model.save_weights('mlp.mnist.initial_weights.hdf5')
history_1 = model.fit(X_train, 
           y_train,
           epochs=epochs, batch_size=batch_size, 
           validation_data = (X_val, y_val),
           verbose=2, 
           callbacks=get_callbacks('mlp.mnist.first_train.hdf5')
          )
# Out:
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.84578, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 1s - loss: 0.5139 - accuracy: 0.8203 - val_loss: 0.4206 - val_accuracy: 0.8458 - lr: 0.0010
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.84578 to 0.85522, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.3614 - accuracy: 0.8702 - val_loss: 0.3975 - val_accuracy: 0.8552 - lr: 0.0010
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.85522 to 0.87789, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.3272 - accuracy: 0.8792 - val_loss: 0.3347 - val_accuracy: 0.8779 - lr: 0.0010
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.87789 to 0.87867, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.2971 - accuracy: 0.8880 - val_loss: 0.3347 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 5/100
#
# Epoch 00005: val_accuracy improved from 0.87867 to 0.88689, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.2800 - accuracy: 0.8964 - val_loss: 0.3155 - val_accuracy: 0.8869 - lr: 0.0010
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.88689 to 0.88844, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.2635 - accuracy: 0.9018 - val_loss: 0.3028 - val_accuracy: 0.8884 - lr: 0.0010
# Epoch 7/100
#
# Epoch 00007: val_accuracy did not improve from 0.88844
# 200/200 - 0s - loss: 0.2454 - accuracy: 0.9070 - val_loss: 0.3272 - val_accuracy: 0.8809 - lr: 0.0010
# Epoch 8/100
#
# Epoch 00008: val_accuracy did not improve from 0.88844
# 200/200 - 0s - loss: 0.2383 - accuracy: 0.9119 - val_loss: 0.3145 - val_accuracy: 0.8852 - lr: 0.0010
# Epoch 9/100
#
# Epoch 00009: val_accuracy improved from 0.88844 to 0.88867, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.2234 - accuracy: 0.9157 - val_loss: 0.3168 - val_accuracy: 0.8887 - lr: 0.0010
# Epoch 10/100
#
# Epoch 00010: val_accuracy improved from 0.88867 to 0.89278, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.2141 - accuracy: 0.9195 - val_loss: 0.2988 - val_accuracy: 0.8928 - lr: 0.0010
# Epoch 11/100
#
# Epoch 00011: val_accuracy did not improve from 0.89278
# 200/200 - 0s - loss: 0.2043 - accuracy: 0.9221 - val_loss: 0.3340 - val_accuracy: 0.8828 - lr: 0.0010
# Epoch 12/100
#
# Epoch 00012: val_accuracy did not improve from 0.89278
# 200/200 - 0s - loss: 0.2000 - accuracy: 0.9245 - val_loss: 0.3164 - val_accuracy: 0.8896 - lr: 0.0010
# Epoch 13/100
#
# Epoch 00013: val_accuracy did not improve from 0.89278
# 200/200 - 0s - loss: 0.1916 - accuracy: 0.9287 - val_loss: 0.3158 - val_accuracy: 0.8923 - lr: 0.0010
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.89278 to 0.89289, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.1836 - accuracy: 0.9299 - val_loss: 0.3060 - val_accuracy: 0.8929 - lr: 0.0010
# Epoch 15/100
#
# Epoch 00015: val_accuracy did not improve from 0.89289
# 200/200 - 0s - loss: 0.1728 - accuracy: 0.9357 - val_loss: 0.3156 - val_accuracy: 0.8912 - lr: 0.0010
# Epoch 16/100
#
# Epoch 00016: val_accuracy improved from 0.89289 to 0.89811, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.1717 - accuracy: 0.9350 - val_loss: 0.3144 - val_accuracy: 0.8981 - lr: 0.0010
# Epoch 17/100
#
# Epoch 00017: val_accuracy did not improve from 0.89811
# 200/200 - 0s - loss: 0.1620 - accuracy: 0.9386 - val_loss: 0.3384 - val_accuracy: 0.8917 - lr: 0.0010
# Epoch 18/100
#
# Epoch 00018: val_accuracy did not improve from 0.89811
# 200/200 - 0s - loss: 0.1552 - accuracy: 0.9407 - val_loss: 0.3266 - val_accuracy: 0.8947 - lr: 0.0010
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.89811
# 200/200 - 0s - loss: 0.1509 - accuracy: 0.9428 - val_loss: 0.3372 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.89811
# 200/200 - 0s - loss: 0.1445 - accuracy: 0.9455 - val_loss: 0.3402 - val_accuracy: 0.8956 - lr: 0.0010
# Epoch 21/100
#
# Epoch 00021: val_accuracy did not improve from 0.89811
# 200/200 - 0s - loss: 0.1357 - accuracy: 0.9479 - val_loss: 0.3483 - val_accuracy: 0.8956 - lr: 0.0010
# Epoch 22/100
#
# Epoch 00022: val_accuracy improved from 0.89811 to 0.89833, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.1401 - accuracy: 0.9468 - val_loss: 0.3351 - val_accuracy: 0.8983 - lr: 0.0010
# Epoch 23/100
#
# Epoch 00023: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1287 - accuracy: 0.9519 - val_loss: 0.3413 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 24/100
#
# Epoch 00024: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1221 - accuracy: 0.9539 - val_loss: 0.3608 - val_accuracy: 0.8906 - lr: 0.0010
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1168 - accuracy: 0.9551 - val_loss: 0.3577 - val_accuracy: 0.8931 - lr: 0.0010
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1137 - accuracy: 0.9564 - val_loss: 0.3570 - val_accuracy: 0.8972 - lr: 0.0010
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1206 - accuracy: 0.9543 - val_loss: 0.3742 - val_accuracy: 0.8942 - lr: 0.0010
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1072 - accuracy: 0.9590 - val_loss: 0.3666 - val_accuracy: 0.8981 - lr: 0.0010
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1056 - accuracy: 0.9595 - val_loss: 0.3977 - val_accuracy: 0.8901 - lr: 0.0010
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.89833
# 200/200 - 0s - loss: 0.1002 - accuracy: 0.9611 - val_loss: 0.3714 - val_accuracy: 0.8963 - lr: 0.0010
# Epoch 31/100
#
# Epoch 00031: val_accuracy improved from 0.89833 to 0.89889, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.0958 - accuracy: 0.9632 - val_loss: 0.3825 - val_accuracy: 0.8989 - lr: 0.0010
# Epoch 32/100
#
# Epoch 00032: val_accuracy did not improve from 0.89889
# 200/200 - 0s - loss: 0.0985 - accuracy: 0.9626 - val_loss: 0.3842 - val_accuracy: 0.8964 - lr: 0.0010
# Epoch 33/100
#
# Epoch 00033: val_accuracy did not improve from 0.89889
# 200/200 - 0s - loss: 0.0879 - accuracy: 0.9669 - val_loss: 0.4009 - val_accuracy: 0.8943 - lr: 0.0010
# Epoch 34/100
#
# Epoch 00034: val_accuracy improved from 0.89889 to 0.89989, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.0855 - accuracy: 0.9682 - val_loss: 0.3811 - val_accuracy: 0.8999 - lr: 0.0010
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0855 - accuracy: 0.9671 - val_loss: 0.4287 - val_accuracy: 0.8928 - lr: 0.0010
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0819 - accuracy: 0.9681 - val_loss: 0.4254 - val_accuracy: 0.8918 - lr: 0.0010
# Epoch 37/100
#
# Epoch 00037: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0753 - accuracy: 0.9710 - val_loss: 0.4390 - val_accuracy: 0.8964 - lr: 0.0010
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0714 - accuracy: 0.9720 - val_loss: 0.4231 - val_accuracy: 0.8973 - lr: 0.0010
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0703 - accuracy: 0.9728 - val_loss: 0.4293 - val_accuracy: 0.8994 - lr: 0.0010
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0712 - accuracy: 0.9732 - val_loss: 0.4278 - val_accuracy: 0.8984 - lr: 0.0010
# Epoch 41/100
#
# Epoch 00041: val_accuracy improved from 0.89989 to 0.90078, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.0701 - accuracy: 0.9737 - val_loss: 0.4386 - val_accuracy: 0.9008 - lr: 0.0010
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0671 - accuracy: 0.9737 - val_loss: 0.4485 - val_accuracy: 0.8961 - lr: 0.0010
# Epoch 43/100
#
# Epoch 00043: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0617 - accuracy: 0.9759 - val_loss: 0.4628 - val_accuracy: 0.8970 - lr: 0.0010
# Epoch 44/100
#
# Epoch 00044: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0627 - accuracy: 0.9760 - val_loss: 0.4725 - val_accuracy: 0.8928 - lr: 0.0010
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0636 - accuracy: 0.9759 - val_loss: 0.4856 - val_accuracy: 0.8979 - lr: 0.0010
# Epoch 46/100
#
# Epoch 00046: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0619 - accuracy: 0.9765 - val_loss: 0.4568 - val_accuracy: 0.8972 - lr: 0.0010
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0541 - accuracy: 0.9793 - val_loss: 0.4809 - val_accuracy: 0.8877 - lr: 0.0010
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0556 - accuracy: 0.9791 - val_loss: 0.4817 - val_accuracy: 0.8964 - lr: 0.0010
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0484 - accuracy: 0.9815 - val_loss: 0.5371 - val_accuracy: 0.8939 - lr: 0.0010
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0491 - accuracy: 0.9820 - val_loss: 0.5100 - val_accuracy: 0.8954 - lr: 0.0010
# Epoch 51/100
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00051: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0523 - accuracy: 0.9797 - val_loss: 0.4930 - val_accuracy: 0.8922 - lr: 0.0010
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0216 - accuracy: 0.9935 - val_loss: 0.5139 - val_accuracy: 0.9002 - lr: 3.1623e-04
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0160 - accuracy: 0.9954 - val_loss: 0.5320 - val_accuracy: 0.9007 - lr: 3.1623e-04
# Epoch 54/100
#
# Epoch 00054: val_accuracy did not improve from 0.90078
# 200/200 - 0s - loss: 0.0141 - accuracy: 0.9959 - val_loss: 0.5413 - val_accuracy: 0.8998 - lr: 3.1623e-04
# Epoch 55/100
#
# Epoch 00055: val_accuracy improved from 0.90078 to 0.90144, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.0127 - accuracy: 0.9969 - val_loss: 0.5570 - val_accuracy: 0.9014 - lr: 3.1623e-04
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.90144
# 200/200 - 0s - loss: 0.0120 - accuracy: 0.9970 - val_loss: 0.5661 - val_accuracy: 0.9001 - lr: 3.1623e-04
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.90144
# 200/200 - 0s - loss: 0.0113 - accuracy: 0.9972 - val_loss: 0.5752 - val_accuracy: 0.9013 - lr: 3.1623e-04
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.90144
# 200/200 - 0s - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.5873 - val_accuracy: 0.9003 - lr: 3.1623e-04
# Epoch 59/100
#
# Epoch 00059: val_accuracy improved from 0.90144 to 0.90178, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.5855 - val_accuracy: 0.9018 - lr: 3.1623e-04
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0099 - accuracy: 0.9976 - val_loss: 0.5950 - val_accuracy: 0.8996 - lr: 3.1623e-04
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0097 - accuracy: 0.9976 - val_loss: 0.6233 - val_accuracy: 0.8991 - lr: 3.1623e-04
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0088 - accuracy: 0.9977 - val_loss: 0.6412 - val_accuracy: 0.8992 - lr: 3.1623e-04
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0094 - accuracy: 0.9974 - val_loss: 0.6398 - val_accuracy: 0.9008 - lr: 3.1623e-04
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0110 - accuracy: 0.9968 - val_loss: 0.6390 - val_accuracy: 0.8993 - lr: 3.1623e-04
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0093 - accuracy: 0.9974 - val_loss: 0.6496 - val_accuracy: 0.8987 - lr: 3.1623e-04
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.6607 - val_accuracy: 0.8990 - lr: 3.1623e-04
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0079 - accuracy: 0.9979 - val_loss: 0.6768 - val_accuracy: 0.9012 - lr: 3.1623e-04
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0076 - accuracy: 0.9979 - val_loss: 0.6814 - val_accuracy: 0.9008 - lr: 3.1623e-04
# Epoch 69/100
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00069: val_accuracy did not improve from 0.90178
# 200/200 - 0s - loss: 0.0103 - accuracy: 0.9972 - val_loss: 0.6682 - val_accuracy: 0.9006 - lr: 3.1623e-04
# Epoch 70/100
#
# Epoch 00070: val_accuracy improved from 0.90178 to 0.90244, saving model to mlp.mnist.first_train.hdf5
# 200/200 - 0s - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.6818 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.6919 - val_accuracy: 0.9013 - lr: 1.0000e-04
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0026 - accuracy: 0.9997 - val_loss: 0.6937 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.7016 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.7077 - val_accuracy: 0.8998 - lr: 1.0000e-04
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.7133 - val_accuracy: 0.9009 - lr: 1.0000e-04
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0023 - accuracy: 0.9998 - val_loss: 0.7196 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.7241 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.7266 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0022 - accuracy: 0.9998 - val_loss: 0.7286 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 80/100
#
# Epoch 00080: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00080: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.7389 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.7400 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.7489 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0018 - accuracy: 0.9999 - val_loss: 0.7645 - val_accuracy: 0.9006 - lr: 1.0000e-04
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.7595 - val_accuracy: 0.9007 - lr: 1.0000e-04
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.7709 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 86/100
#
# Epoch 00086: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.7757 - val_accuracy: 0.9010 - lr: 1.0000e-04
# Epoch 87/100
#
# Epoch 00087: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7758 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 88/100
#
# Epoch 00088: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.7850 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 89/100
#
# Epoch 00089: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7860 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 90/100
#
# Epoch 00090: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8000 - val_accuracy: 0.8998 - lr: 1.0000e-04
# Epoch 91/100
#
# Epoch 00091: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.8035 - val_accuracy: 0.9006 - lr: 1.0000e-04
# Epoch 92/100
#
# Epoch 00092: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.8119 - val_accuracy: 0.9006 - lr: 1.0000e-04
# Epoch 93/100
#
# Epoch 00093: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.8072 - val_accuracy: 0.8993 - lr: 1.0000e-04
# Epoch 94/100
#
# Epoch 00094: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 9.9886e-04 - accuracy: 1.0000 - val_loss: 0.8240 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 95/100
#
# Epoch 00095: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 8.2809e-04 - accuracy: 1.0000 - val_loss: 0.8298 - val_accuracy: 0.9009 - lr: 1.0000e-04
# Epoch 96/100
#
# Epoch 00096: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 8.2439e-04 - accuracy: 1.0000 - val_loss: 0.8316 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 97/100
#
# Epoch 00097: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 7.6903e-04 - accuracy: 1.0000 - val_loss: 0.8340 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 98/100
#
# Epoch 00098: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 8.0460e-04 - accuracy: 1.0000 - val_loss: 0.8384 - val_accuracy: 0.9009 - lr: 1.0000e-04
# Epoch 99/100
#
# Epoch 00099: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 7.5683e-04 - accuracy: 1.0000 - val_loss: 0.8449 - val_accuracy: 0.9007 - lr: 1.0000e-04
# Epoch 100/100
#
# Epoch 00100: val_accuracy did not improve from 0.90244
# 200/200 - 0s - loss: 6.7861e-04 - accuracy: 1.0000 - val_loss: 0.8581 - val_accuracy: 0.9006 - lr: 1.0000e-04

# %%
model.evaluate(X_val, y_val, verbose=0)
# Out:
# [0.8580614924430847, 0.9005555510520935]

# %%
model.load_weights('mlp.mnist.first_train.hdf5')
print(model.evaluate(X_val, y_val, verbose=0), model.evaluate(X_test, y_test, verbose=0))
# Out:
# [0.68180251121521, 0.9024444222450256] [0.7717013955116272, 0.9003999829292297]

# %% [markdown]
# # Step 3. Get Trainned pruned model

# %%
# Get prunned model with correct mask
pm = 0.5 # Porcentage of weights not pruned
model_pruned_trained = lth.get_prunned_model('mlp.mnist.first_train.hdf5', pm)
# Out:
# WARNING:tensorflow:From /home/usuario/anaconda3/envs/tensorflow2/lib/python3.6/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:199: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.

# %%
model_pruned_trained.evaluate(X_test, y_test)
# Out:
# 313/313 [==============================] - 0s 798us/step - loss: 0.6945 - accuracy: 0.8969
# [0.6945029497146606, 0.8968999981880188]

# %%
# model_initialized = lth.initialize_sparse_model('mlp.mnist.first_train.hdf5', model_pruned_layers_trained, pm)
# model_initialized.evaluate(X_test, y_test)

# %%
#lth.verify_mask_with_model_min_weights('mlp.mnist.first_train.hdf5', model_pruned_layers_trained)

# %%
# It has to be false beacuase the model is not trained
# lth.verify_mask_with_model_min_weights('mlp.mnist.initial_weights.hdf5', model_pruned_layers_trained)

# %% [markdown]
# # Step 4. Prune initial random weights

# %%
pruned_model_not_trained = lth.initialize_sparse_model('mlp.mnist.initial_weights.hdf5', model_pruned_trained, pm)
# lth.test_model_sparsity(pruned_model_not_trained)
# print(f'Acc: {pruned_model_not_trained.evaluate(X_test, y_test, verbose=0)[1]}, Sparcity: {l1_sparc}')

# %%
# lth.verify_mask_with_model_min_weights(pruned_model, model_pruned_layers_trained)

# %% [markdown]
# # Train pruned model

# %%
def get_prunned_callbacks(filename):
    return get_callbacks(filename) + [tfmot.sparsity.keras.UpdatePruningStep()]

# %%
compile_model(pruned_model_not_trained)
history_2 = pruned_model_not_trained.fit(X_train, 
               y_train,
               epochs=epochs, batch_size=batch_size, 
              validation_data = (X_val, y_val),
               verbose=2, 
                    shuffle = True,
                           callbacks=get_prunned_callbacks('mlp.mnist.sparse_train.hdf5')
              )
# Out:
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.84911, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.5773 - accuracy: 0.8033 - val_loss: 0.4241 - val_accuracy: 0.8491 - lr: 0.0010
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.84911 to 0.86378, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.3873 - accuracy: 0.8628 - val_loss: 0.3881 - val_accuracy: 0.8638 - lr: 0.0010
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.86378 to 0.87933, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.3387 - accuracy: 0.8784 - val_loss: 0.3429 - val_accuracy: 0.8793 - lr: 0.0010
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.87933 to 0.87956, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.3079 - accuracy: 0.8870 - val_loss: 0.3397 - val_accuracy: 0.8796 - lr: 0.0010
# Epoch 5/100
#
# Epoch 00005: val_accuracy improved from 0.87956 to 0.88189, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.2866 - accuracy: 0.8941 - val_loss: 0.3327 - val_accuracy: 0.8819 - lr: 0.0010
# Epoch 6/100
#
# Epoch 00006: val_accuracy improved from 0.88189 to 0.88211, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.2692 - accuracy: 0.9009 - val_loss: 0.3377 - val_accuracy: 0.8821 - lr: 0.0010
# Epoch 7/100
#
# Epoch 00007: val_accuracy improved from 0.88211 to 0.88900, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.2555 - accuracy: 0.9052 - val_loss: 0.3095 - val_accuracy: 0.8890 - lr: 0.0010
# Epoch 8/100
#
# Epoch 00008: val_accuracy did not improve from 0.88900
# 200/200 - 0s - loss: 0.2409 - accuracy: 0.9097 - val_loss: 0.3175 - val_accuracy: 0.8844 - lr: 0.0010
# Epoch 9/100
#
# Epoch 00009: val_accuracy did not improve from 0.88900
# 200/200 - 0s - loss: 0.2280 - accuracy: 0.9160 - val_loss: 0.3138 - val_accuracy: 0.8881 - lr: 0.0010
# Epoch 10/100
#
# Epoch 00010: val_accuracy improved from 0.88900 to 0.89111, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.2177 - accuracy: 0.9200 - val_loss: 0.3105 - val_accuracy: 0.8911 - lr: 0.0010
# Epoch 11/100
#
# Epoch 00011: val_accuracy did not improve from 0.89111
# 200/200 - 0s - loss: 0.2070 - accuracy: 0.9233 - val_loss: 0.3360 - val_accuracy: 0.8814 - lr: 0.0010
# Epoch 12/100
#
# Epoch 00012: val_accuracy did not improve from 0.89111
# 200/200 - 0s - loss: 0.2004 - accuracy: 0.9248 - val_loss: 0.3186 - val_accuracy: 0.8903 - lr: 0.0010
# Epoch 13/100
#
# Epoch 00013: val_accuracy improved from 0.89111 to 0.89122, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.1869 - accuracy: 0.9294 - val_loss: 0.3090 - val_accuracy: 0.8912 - lr: 0.0010
# Epoch 14/100
#
# Epoch 00014: val_accuracy improved from 0.89122 to 0.89456, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.1809 - accuracy: 0.9328 - val_loss: 0.3049 - val_accuracy: 0.8946 - lr: 0.0010
# Epoch 15/100
#
# Epoch 00015: val_accuracy did not improve from 0.89456
# 200/200 - 1s - loss: 0.1721 - accuracy: 0.9354 - val_loss: 0.3470 - val_accuracy: 0.8893 - lr: 0.0010
# Epoch 16/100
#
# Epoch 00016: val_accuracy did not improve from 0.89456
# 200/200 - 1s - loss: 0.1626 - accuracy: 0.9395 - val_loss: 0.3193 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 17/100
#
# Epoch 00017: val_accuracy improved from 0.89456 to 0.89500, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.1551 - accuracy: 0.9424 - val_loss: 0.3153 - val_accuracy: 0.8950 - lr: 0.0010
# Epoch 18/100
#
# Epoch 00018: val_accuracy did not improve from 0.89500
# 200/200 - 1s - loss: 0.1532 - accuracy: 0.9429 - val_loss: 0.3238 - val_accuracy: 0.8930 - lr: 0.0010
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.89500
# 200/200 - 0s - loss: 0.1456 - accuracy: 0.9466 - val_loss: 0.3177 - val_accuracy: 0.8949 - lr: 0.0010
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.89500
# 200/200 - 0s - loss: 0.1420 - accuracy: 0.9470 - val_loss: 0.3353 - val_accuracy: 0.8924 - lr: 0.0010
# Epoch 21/100
#
# Epoch 00021: val_accuracy did not improve from 0.89500
# 200/200 - 1s - loss: 0.1359 - accuracy: 0.9476 - val_loss: 0.3382 - val_accuracy: 0.8934 - lr: 0.0010
# Epoch 22/100
#
# Epoch 00022: val_accuracy did not improve from 0.89500
# 200/200 - 0s - loss: 0.1256 - accuracy: 0.9520 - val_loss: 0.3317 - val_accuracy: 0.8942 - lr: 0.0010
# Epoch 23/100
#
# Epoch 00023: val_accuracy improved from 0.89500 to 0.90022, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.1233 - accuracy: 0.9536 - val_loss: 0.3376 - val_accuracy: 0.9002 - lr: 0.0010
# Epoch 24/100
#
# Epoch 00024: val_accuracy did not improve from 0.90022
# 200/200 - 1s - loss: 0.1166 - accuracy: 0.9564 - val_loss: 0.3437 - val_accuracy: 0.8983 - lr: 0.0010
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.90022
# 200/200 - 0s - loss: 0.1114 - accuracy: 0.9586 - val_loss: 0.3548 - val_accuracy: 0.8937 - lr: 0.0010
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.90022
# 200/200 - 1s - loss: 0.1066 - accuracy: 0.9592 - val_loss: 0.3572 - val_accuracy: 0.8964 - lr: 0.0010
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.90022
# 200/200 - 1s - loss: 0.0995 - accuracy: 0.9632 - val_loss: 0.3745 - val_accuracy: 0.8932 - lr: 0.0010
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.90022
# 200/200 - 0s - loss: 0.0940 - accuracy: 0.9645 - val_loss: 0.3936 - val_accuracy: 0.8894 - lr: 0.0010
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.90022
# 200/200 - 1s - loss: 0.0959 - accuracy: 0.9643 - val_loss: 0.3739 - val_accuracy: 0.8968 - lr: 0.0010
# Epoch 30/100
#
# Epoch 00030: val_accuracy did not improve from 0.90022
# 200/200 - 1s - loss: 0.0897 - accuracy: 0.9656 - val_loss: 0.4355 - val_accuracy: 0.8842 - lr: 0.0010
# Epoch 31/100
#
# Epoch 00031: val_accuracy did not improve from 0.90022
# 200/200 - 0s - loss: 0.0910 - accuracy: 0.9661 - val_loss: 0.3937 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 32/100
#
# Epoch 00032: val_accuracy did not improve from 0.90022
# 200/200 - 1s - loss: 0.0811 - accuracy: 0.9693 - val_loss: 0.4088 - val_accuracy: 0.8939 - lr: 0.0010
# Epoch 33/100
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00033: val_accuracy did not improve from 0.90022
# 200/200 - 0s - loss: 0.0730 - accuracy: 0.9732 - val_loss: 0.4048 - val_accuracy: 0.8968 - lr: 0.0010
# Epoch 34/100
#
# Epoch 00034: val_accuracy improved from 0.90022 to 0.90289, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 1s - loss: 0.0479 - accuracy: 0.9830 - val_loss: 0.3959 - val_accuracy: 0.9029 - lr: 3.1623e-04
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.90289
# 200/200 - 1s - loss: 0.0404 - accuracy: 0.9861 - val_loss: 0.4124 - val_accuracy: 0.9028 - lr: 3.1623e-04
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0388 - accuracy: 0.9875 - val_loss: 0.4172 - val_accuracy: 0.9019 - lr: 3.1623e-04
# Epoch 37/100
#
# Epoch 00037: val_accuracy did not improve from 0.90289
# 200/200 - 1s - loss: 0.0359 - accuracy: 0.9886 - val_loss: 0.4289 - val_accuracy: 0.9013 - lr: 3.1623e-04
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.90289
# 200/200 - 1s - loss: 0.0345 - accuracy: 0.9892 - val_loss: 0.4331 - val_accuracy: 0.9019 - lr: 3.1623e-04
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0328 - accuracy: 0.9894 - val_loss: 0.4443 - val_accuracy: 0.9016 - lr: 3.1623e-04
# Epoch 40/100
#
# Epoch 00040: val_accuracy did not improve from 0.90289
# 200/200 - 1s - loss: 0.0319 - accuracy: 0.9902 - val_loss: 0.4519 - val_accuracy: 0.8988 - lr: 3.1623e-04
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0310 - accuracy: 0.9906 - val_loss: 0.4505 - val_accuracy: 0.9024 - lr: 3.1623e-04
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0277 - accuracy: 0.9913 - val_loss: 0.4596 - val_accuracy: 0.9018 - lr: 3.1623e-04
# Epoch 43/100
#
# Epoch 00043: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0283 - accuracy: 0.9909 - val_loss: 0.4726 - val_accuracy: 0.9004 - lr: 3.1623e-04
# Epoch 44/100
#
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00044: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0250 - accuracy: 0.9925 - val_loss: 0.4748 - val_accuracy: 0.9011 - lr: 3.1623e-04
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0184 - accuracy: 0.9958 - val_loss: 0.4789 - val_accuracy: 0.9028 - lr: 1.0000e-04
# Epoch 46/100
#
# Epoch 00046: val_accuracy improved from 0.90289 to 0.90311, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 0s - loss: 0.0167 - accuracy: 0.9965 - val_loss: 0.4856 - val_accuracy: 0.9031 - lr: 1.0000e-04
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.90311
# 200/200 - 0s - loss: 0.0163 - accuracy: 0.9964 - val_loss: 0.4905 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 48/100
#
# Epoch 00048: val_accuracy improved from 0.90311 to 0.90322, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 0s - loss: 0.0157 - accuracy: 0.9967 - val_loss: 0.4986 - val_accuracy: 0.9032 - lr: 1.0000e-04
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.90322
# 200/200 - 0s - loss: 0.0155 - accuracy: 0.9966 - val_loss: 0.4935 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.90322
# 200/200 - 0s - loss: 0.0148 - accuracy: 0.9969 - val_loss: 0.5009 - val_accuracy: 0.9029 - lr: 1.0000e-04
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.90322
# 200/200 - 0s - loss: 0.0144 - accuracy: 0.9969 - val_loss: 0.5044 - val_accuracy: 0.9028 - lr: 1.0000e-04
# Epoch 52/100
#
# Epoch 00052: val_accuracy improved from 0.90322 to 0.90367, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 0s - loss: 0.0138 - accuracy: 0.9975 - val_loss: 0.5112 - val_accuracy: 0.9037 - lr: 1.0000e-04
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 0.0134 - accuracy: 0.9974 - val_loss: 0.5132 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 54/100
#
# Epoch 00054: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 0.0131 - accuracy: 0.9974 - val_loss: 0.5174 - val_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 55/100
#
# Epoch 00055: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 0.0125 - accuracy: 0.9975 - val_loss: 0.5241 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 56/100
#
# Epoch 00056: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 0.0123 - accuracy: 0.9978 - val_loss: 0.5276 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 0.0118 - accuracy: 0.9978 - val_loss: 0.5293 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 0.0112 - accuracy: 0.9980 - val_loss: 0.5335 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 59/100
#
# Epoch 00059: val_accuracy improved from 0.90367 to 0.90400, saving model to mlp.mnist.sparse_train.hdf5
# 200/200 - 0s - loss: 0.0111 - accuracy: 0.9982 - val_loss: 0.5385 - val_accuracy: 0.9040 - lr: 1.0000e-04
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0109 - accuracy: 0.9979 - val_loss: 0.5400 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0101 - accuracy: 0.9985 - val_loss: 0.5452 - val_accuracy: 0.9020 - lr: 1.0000e-04
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.5535 - val_accuracy: 0.9027 - lr: 1.0000e-04
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0091 - accuracy: 0.9985 - val_loss: 0.5569 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0093 - accuracy: 0.9985 - val_loss: 0.5652 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.5686 - val_accuracy: 0.9034 - lr: 1.0000e-04
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0082 - accuracy: 0.9989 - val_loss: 0.5743 - val_accuracy: 0.9028 - lr: 1.0000e-04
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0077 - accuracy: 0.9990 - val_loss: 0.5770 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0078 - accuracy: 0.9988 - val_loss: 0.5816 - val_accuracy: 0.9032 - lr: 1.0000e-04
# Epoch 69/100
#
# Epoch 00069: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00069: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0074 - accuracy: 0.9992 - val_loss: 0.5857 - val_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0069 - accuracy: 0.9991 - val_loss: 0.5911 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0067 - accuracy: 0.9992 - val_loss: 0.6012 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0063 - accuracy: 0.9993 - val_loss: 0.6026 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0060 - accuracy: 0.9993 - val_loss: 0.6044 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0059 - accuracy: 0.9992 - val_loss: 0.6227 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0057 - accuracy: 0.9994 - val_loss: 0.6227 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0054 - accuracy: 0.9993 - val_loss: 0.6269 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0052 - accuracy: 0.9993 - val_loss: 0.6317 - val_accuracy: 0.9007 - lr: 1.0000e-04
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0048 - accuracy: 0.9996 - val_loss: 0.6349 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0049 - accuracy: 0.9996 - val_loss: 0.6430 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 80/100
#
# Epoch 00080: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0046 - accuracy: 0.9995 - val_loss: 0.6511 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0043 - accuracy: 0.9995 - val_loss: 0.6574 - val_accuracy: 0.8999 - lr: 1.0000e-04
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0043 - accuracy: 0.9996 - val_loss: 0.6640 - val_accuracy: 0.9001 - lr: 1.0000e-04
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0037 - accuracy: 0.9997 - val_loss: 0.6591 - val_accuracy: 0.9007 - lr: 1.0000e-04
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0038 - accuracy: 0.9996 - val_loss: 0.6678 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.6828 - val_accuracy: 0.8990 - lr: 1.0000e-04
# Epoch 86/100
#
# Epoch 00086: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0034 - accuracy: 0.9998 - val_loss: 0.6781 - val_accuracy: 0.8999 - lr: 1.0000e-04
# Epoch 87/100
#
# Epoch 00087: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0032 - accuracy: 0.9999 - val_loss: 0.6840 - val_accuracy: 0.9006 - lr: 1.0000e-04
# Epoch 88/100
#
# Epoch 00088: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0031 - accuracy: 0.9998 - val_loss: 0.6833 - val_accuracy: 0.9020 - lr: 1.0000e-04
# Epoch 89/100
#
# Epoch 00089: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0029 - accuracy: 0.9998 - val_loss: 0.7017 - val_accuracy: 0.8990 - lr: 1.0000e-04
# Epoch 90/100
#
# Epoch 00090: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0029 - accuracy: 0.9999 - val_loss: 0.7161 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 91/100
#
# Epoch 00091: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0027 - accuracy: 0.9998 - val_loss: 0.7063 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 92/100
#
# Epoch 00092: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0026 - accuracy: 0.9999 - val_loss: 0.7154 - val_accuracy: 0.9006 - lr: 1.0000e-04
# Epoch 93/100
#
# Epoch 00093: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.7132 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 94/100
#
# Epoch 00094: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.7301 - val_accuracy: 0.8997 - lr: 1.0000e-04
# Epoch 95/100
#
# Epoch 00095: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.7314 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 96/100
#
# Epoch 00096: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.7350 - val_accuracy: 0.9008 - lr: 1.0000e-04
# Epoch 97/100
#
# Epoch 00097: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0028 - accuracy: 0.9998 - val_loss: 0.7375 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 98/100
#
# Epoch 00098: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7574 - val_accuracy: 0.8999 - lr: 1.0000e-04
# Epoch 99/100
#
# Epoch 00099: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0019 - accuracy: 0.9999 - val_loss: 0.7492 - val_accuracy: 0.8999 - lr: 1.0000e-04
# Epoch 100/100
#
# Epoch 00100: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7561 - val_accuracy: 0.9008 - lr: 1.0000e-04

# %%
pruned_model_not_trained.evaluate(X_val, y_val, verbose=0)
# Out:
# [0.7561230063438416, 0.9007777571678162]

# %%
pruned_model_not_trained.load_weights('mlp.mnist.sparse_train.hdf5')
print(pruned_model_not_trained.evaluate(X_val, y_val, verbose=0))
pruned_model_not_trained.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.5385008454322815, 0.9039999842643738]
# [0.5790573358535767, 0.8988999724388123]

# %%
plt.plot(history_1.history['val_accuracy'])
plt.plot(history_2.history['val_accuracy'])

# %% [markdown]
# # Re-train reducing pm

# %%
# Pruned layer to Dense
trained_striped_model = tfmot.sparsity.keras.strip_pruning(pruned_model_not_trained)
# Save weights
trained_striped_model.save_weights('mlp.mnist.sparse_train_striped.hdf5')

# %%
new_pm = pm**(1/2)*pm
print(new_pm)
# Out:
# 0.3535533905932738

# %%
pruned_model_2 = lth.get_prunned_model('mlp.mnist.sparse_train_striped.hdf5', new_pm)

# %%
untrained_pruned_model_2 = lth.initialize_sparse_model('mlp.mnist.initial_weights.hdf5', pruned_model_2, new_pm)
compile_model(pruned_model_2)

# %%
history_3 = pruned_model_2.fit(X_train, 
               y_train,
               epochs=epochs, batch_size=batch_size, 
              validation_data = (X_val, y_val),
               verbose=2, 
                    shuffle = True,
                           callbacks=get_prunned_callbacks('mlp.mnist.sparse_train_2.hdf5')
              )
# Out:
# Epoch 1/100
#
# Epoch 00001: val_accuracy improved from -inf to 0.89389, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 1s - loss: 0.0399 - accuracy: 0.9855 - val_loss: 0.5500 - val_accuracy: 0.8939 - lr: 0.0010
# Epoch 2/100
#
# Epoch 00002: val_accuracy improved from 0.89389 to 0.89444, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 0.0369 - accuracy: 0.9868 - val_loss: 0.5390 - val_accuracy: 0.8944 - lr: 0.0010
# Epoch 3/100
#
# Epoch 00003: val_accuracy improved from 0.89444 to 0.89544, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 1s - loss: 0.0399 - accuracy: 0.9851 - val_loss: 0.5446 - val_accuracy: 0.8954 - lr: 0.0010
# Epoch 4/100
#
# Epoch 00004: val_accuracy improved from 0.89544 to 0.89900, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 1s - loss: 0.0314 - accuracy: 0.9889 - val_loss: 0.5365 - val_accuracy: 0.8990 - lr: 0.0010
# Epoch 5/100
#
# Epoch 00005: val_accuracy did not improve from 0.89900
# 200/200 - 0s - loss: 0.0307 - accuracy: 0.9886 - val_loss: 0.5936 - val_accuracy: 0.8946 - lr: 0.0010
# Epoch 6/100
#
# Epoch 00006: val_accuracy did not improve from 0.89900
# 200/200 - 0s - loss: 0.0367 - accuracy: 0.9860 - val_loss: 0.5569 - val_accuracy: 0.8949 - lr: 0.0010
# Epoch 7/100
#
# Epoch 00007: val_accuracy did not improve from 0.89900
# 200/200 - 0s - loss: 0.0339 - accuracy: 0.9877 - val_loss: 0.5481 - val_accuracy: 0.8990 - lr: 0.0010
# Epoch 8/100
#
# Epoch 00008: val_accuracy did not improve from 0.89900
# 200/200 - 0s - loss: 0.0260 - accuracy: 0.9909 - val_loss: 0.5683 - val_accuracy: 0.8956 - lr: 0.0010
# Epoch 9/100
#
# Epoch 00009: val_accuracy did not improve from 0.89900
# 200/200 - 0s - loss: 0.0320 - accuracy: 0.9885 - val_loss: 0.5750 - val_accuracy: 0.8950 - lr: 0.0010
# Epoch 10/100
#
# Epoch 00010: val_accuracy did not improve from 0.89900
# 200/200 - 0s - loss: 0.0275 - accuracy: 0.9908 - val_loss: 0.5874 - val_accuracy: 0.8952 - lr: 0.0010
# Epoch 11/100
#
# Epoch 00011: val_accuracy improved from 0.89900 to 0.89989, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 1s - loss: 0.0234 - accuracy: 0.9917 - val_loss: 0.5898 - val_accuracy: 0.8999 - lr: 0.0010
# Epoch 12/100
#
# Epoch 00012: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0283 - accuracy: 0.9897 - val_loss: 0.6030 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 13/100
#
# Epoch 00013: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0231 - accuracy: 0.9922 - val_loss: 0.6722 - val_accuracy: 0.8933 - lr: 0.0010
# Epoch 14/100
#
# Epoch 00014: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0320 - accuracy: 0.9883 - val_loss: 0.6369 - val_accuracy: 0.8971 - lr: 0.0010
# Epoch 15/100
#
# Epoch 00015: val_accuracy did not improve from 0.89989
# 200/200 - 1s - loss: 0.0247 - accuracy: 0.9915 - val_loss: 0.6315 - val_accuracy: 0.8977 - lr: 0.0010
# Epoch 16/100
#
# Epoch 00016: val_accuracy did not improve from 0.89989
# 200/200 - 1s - loss: 0.0199 - accuracy: 0.9931 - val_loss: 0.6445 - val_accuracy: 0.8963 - lr: 0.0010
# Epoch 17/100
#
# Epoch 00017: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0207 - accuracy: 0.9926 - val_loss: 0.6564 - val_accuracy: 0.8943 - lr: 0.0010
# Epoch 18/100
#
# Epoch 00018: val_accuracy did not improve from 0.89989
# 200/200 - 1s - loss: 0.0340 - accuracy: 0.9875 - val_loss: 0.6298 - val_accuracy: 0.8967 - lr: 0.0010
# Epoch 19/100
#
# Epoch 00019: val_accuracy did not improve from 0.89989
# 200/200 - 1s - loss: 0.0185 - accuracy: 0.9939 - val_loss: 0.6587 - val_accuracy: 0.8932 - lr: 0.0010
# Epoch 20/100
#
# Epoch 00020: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0194 - accuracy: 0.9933 - val_loss: 0.6646 - val_accuracy: 0.8979 - lr: 0.0010
# Epoch 21/100
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 00021: val_accuracy did not improve from 0.89989
# 200/200 - 0s - loss: 0.0182 - accuracy: 0.9936 - val_loss: 0.6642 - val_accuracy: 0.8981 - lr: 0.0010
# Epoch 22/100
#
# Epoch 00022: val_accuracy improved from 0.89989 to 0.90222, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 0.0068 - accuracy: 0.9985 - val_loss: 0.6515 - val_accuracy: 0.9022 - lr: 3.1623e-04
# Epoch 23/100
#
# Epoch 00023: val_accuracy improved from 0.90222 to 0.90267, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.6693 - val_accuracy: 0.9027 - lr: 3.1623e-04
# Epoch 24/100
#
# Epoch 00024: val_accuracy improved from 0.90267 to 0.90278, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 0.0028 - accuracy: 0.9997 - val_loss: 0.6810 - val_accuracy: 0.9028 - lr: 3.1623e-04
# Epoch 25/100
#
# Epoch 00025: val_accuracy did not improve from 0.90278
# 200/200 - 0s - loss: 0.0025 - accuracy: 0.9998 - val_loss: 0.6932 - val_accuracy: 0.9021 - lr: 3.1623e-04
# Epoch 26/100
#
# Epoch 00026: val_accuracy did not improve from 0.90278
# 200/200 - 0s - loss: 0.0024 - accuracy: 0.9998 - val_loss: 0.6964 - val_accuracy: 0.9027 - lr: 3.1623e-04
# Epoch 27/100
#
# Epoch 00027: val_accuracy did not improve from 0.90278
# 200/200 - 0s - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.7052 - val_accuracy: 0.9018 - lr: 3.1623e-04
# Epoch 28/100
#
# Epoch 00028: val_accuracy did not improve from 0.90278
# 200/200 - 0s - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.7112 - val_accuracy: 0.9022 - lr: 3.1623e-04
# Epoch 29/100
#
# Epoch 00029: val_accuracy did not improve from 0.90278
# 200/200 - 0s - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.7252 - val_accuracy: 0.9018 - lr: 3.1623e-04
# Epoch 30/100
#
# Epoch 00030: val_accuracy improved from 0.90278 to 0.90289, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.7240 - val_accuracy: 0.9029 - lr: 3.1623e-04
# Epoch 31/100
#
# Epoch 00031: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.7332 - val_accuracy: 0.9029 - lr: 3.1623e-04
# Epoch 32/100
#
# Epoch 00032: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.7427 - val_accuracy: 0.9027 - lr: 3.1623e-04
# Epoch 33/100
#
# Epoch 00033: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.7478 - val_accuracy: 0.9006 - lr: 3.1623e-04
# Epoch 34/100
#
# Epoch 00034: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0017 - accuracy: 0.9999 - val_loss: 0.7413 - val_accuracy: 0.9020 - lr: 3.1623e-04
# Epoch 35/100
#
# Epoch 00035: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.7692 - val_accuracy: 0.9024 - lr: 3.1623e-04
# Epoch 36/100
#
# Epoch 00036: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.7605 - val_accuracy: 0.8997 - lr: 3.1623e-04
# Epoch 37/100
#
# Epoch 00037: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.7687 - val_accuracy: 0.8974 - lr: 3.1623e-04
# Epoch 38/100
#
# Epoch 00038: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0055 - accuracy: 0.9987 - val_loss: 0.7461 - val_accuracy: 0.9008 - lr: 3.1623e-04
# Epoch 39/100
#
# Epoch 00039: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.7617 - val_accuracy: 0.9016 - lr: 3.1623e-04
# Epoch 40/100
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 00040: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 0.0017 - accuracy: 0.9998 - val_loss: 0.7667 - val_accuracy: 0.9014 - lr: 3.1623e-04
# Epoch 41/100
#
# Epoch 00041: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 8.7077e-04 - accuracy: 1.0000 - val_loss: 0.7695 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 42/100
#
# Epoch 00042: val_accuracy did not improve from 0.90289
# 200/200 - 0s - loss: 6.8868e-04 - accuracy: 1.0000 - val_loss: 0.7775 - val_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 43/100
#
# Epoch 00043: val_accuracy improved from 0.90289 to 0.90367, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 6.3739e-04 - accuracy: 1.0000 - val_loss: 0.7795 - val_accuracy: 0.9037 - lr: 1.0000e-04
# Epoch 44/100
#
# Epoch 00044: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 6.2197e-04 - accuracy: 1.0000 - val_loss: 0.7838 - val_accuracy: 0.9028 - lr: 1.0000e-04
# Epoch 45/100
#
# Epoch 00045: val_accuracy did not improve from 0.90367
# 200/200 - 0s - loss: 5.8374e-04 - accuracy: 1.0000 - val_loss: 0.7901 - val_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 46/100
#
# Epoch 00046: val_accuracy improved from 0.90367 to 0.90400, saving model to mlp.mnist.sparse_train_2.hdf5
# 200/200 - 0s - loss: 5.6439e-04 - accuracy: 1.0000 - val_loss: 0.7920 - val_accuracy: 0.9040 - lr: 1.0000e-04
# Epoch 47/100
#
# Epoch 00047: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 5.5745e-04 - accuracy: 1.0000 - val_loss: 0.7946 - val_accuracy: 0.9030 - lr: 1.0000e-04
# Epoch 48/100
#
# Epoch 00048: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 5.3415e-04 - accuracy: 1.0000 - val_loss: 0.7983 - val_accuracy: 0.9027 - lr: 1.0000e-04
# Epoch 49/100
#
# Epoch 00049: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 5.2262e-04 - accuracy: 1.0000 - val_loss: 0.8006 - val_accuracy: 0.9028 - lr: 1.0000e-04
# Epoch 50/100
#
# Epoch 00050: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 5.0825e-04 - accuracy: 1.0000 - val_loss: 0.8074 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 51/100
#
# Epoch 00051: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.9513e-04 - accuracy: 1.0000 - val_loss: 0.8095 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 52/100
#
# Epoch 00052: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.8492e-04 - accuracy: 1.0000 - val_loss: 0.8124 - val_accuracy: 0.9030 - lr: 1.0000e-04
# Epoch 53/100
#
# Epoch 00053: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.6559e-04 - accuracy: 1.0000 - val_loss: 0.8160 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 54/100
#
# Epoch 00054: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.4307e-04 - accuracy: 1.0000 - val_loss: 0.8199 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 55/100
#
# Epoch 00055: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.5945e-04 - accuracy: 1.0000 - val_loss: 0.8262 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 56/100
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00056: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.0744e-04 - accuracy: 1.0000 - val_loss: 0.8297 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 57/100
#
# Epoch 00057: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.9897e-04 - accuracy: 1.0000 - val_loss: 0.8314 - val_accuracy: 0.9029 - lr: 1.0000e-04
# Epoch 58/100
#
# Epoch 00058: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.8005e-04 - accuracy: 1.0000 - val_loss: 0.8407 - val_accuracy: 0.9027 - lr: 1.0000e-04
# Epoch 59/100
#
# Epoch 00059: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.5662e-04 - accuracy: 1.0000 - val_loss: 0.8420 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 60/100
#
# Epoch 00060: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.5468e-04 - accuracy: 1.0000 - val_loss: 0.8463 - val_accuracy: 0.9033 - lr: 1.0000e-04
# Epoch 61/100
#
# Epoch 00061: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.5250e-04 - accuracy: 1.0000 - val_loss: 0.8489 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 62/100
#
# Epoch 00062: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.1723e-04 - accuracy: 1.0000 - val_loss: 0.8529 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 63/100
#
# Epoch 00063: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.0645e-04 - accuracy: 1.0000 - val_loss: 0.8610 - val_accuracy: 0.9022 - lr: 1.0000e-04
# Epoch 64/100
#
# Epoch 00064: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 3.0697e-04 - accuracy: 1.0000 - val_loss: 0.8635 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 65/100
#
# Epoch 00065: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 2.9349e-04 - accuracy: 1.0000 - val_loss: 0.8706 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 66/100
#
# Epoch 00066: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 2.5729e-04 - accuracy: 1.0000 - val_loss: 0.8798 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 67/100
#
# Epoch 00067: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 6.8349e-04 - accuracy: 0.9999 - val_loss: 0.8843 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 68/100
#
# Epoch 00068: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0010 - accuracy: 0.9999 - val_loss: 0.8677 - val_accuracy: 0.9010 - lr: 1.0000e-04
# Epoch 69/100
#
# Epoch 00069: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 2.7285e-04 - accuracy: 1.0000 - val_loss: 0.8775 - val_accuracy: 0.9011 - lr: 1.0000e-04
# Epoch 70/100
#
# Epoch 00070: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 2.2034e-04 - accuracy: 1.0000 - val_loss: 0.8857 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 71/100
#
# Epoch 00071: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.9901e-04 - accuracy: 1.0000 - val_loss: 0.8903 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 72/100
#
# Epoch 00072: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.8530e-04 - accuracy: 1.0000 - val_loss: 0.8932 - val_accuracy: 0.9029 - lr: 1.0000e-04
# Epoch 73/100
#
# Epoch 00073: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.7968e-04 - accuracy: 1.0000 - val_loss: 0.8993 - val_accuracy: 0.9029 - lr: 1.0000e-04
# Epoch 74/100
#
# Epoch 00074: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.7184e-04 - accuracy: 1.0000 - val_loss: 0.9063 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 75/100
#
# Epoch 00075: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.6616e-04 - accuracy: 1.0000 - val_loss: 0.9091 - val_accuracy: 0.9026 - lr: 1.0000e-04
# Epoch 76/100
#
# Epoch 00076: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.6036e-04 - accuracy: 1.0000 - val_loss: 0.9138 - val_accuracy: 0.9020 - lr: 1.0000e-04
# Epoch 77/100
#
# Epoch 00077: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.5349e-04 - accuracy: 1.0000 - val_loss: 0.9198 - val_accuracy: 0.9021 - lr: 1.0000e-04
# Epoch 78/100
#
# Epoch 00078: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.4813e-04 - accuracy: 1.0000 - val_loss: 0.9207 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 79/100
#
# Epoch 00079: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.4135e-04 - accuracy: 1.0000 - val_loss: 0.9238 - val_accuracy: 0.9013 - lr: 1.0000e-04
# Epoch 80/100
#
# Epoch 00080: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.3907e-04 - accuracy: 1.0000 - val_loss: 0.9295 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 81/100
#
# Epoch 00081: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.3537e-04 - accuracy: 1.0000 - val_loss: 0.9366 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 82/100
#
# Epoch 00082: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.2762e-04 - accuracy: 1.0000 - val_loss: 0.9451 - val_accuracy: 0.9009 - lr: 1.0000e-04
# Epoch 83/100
#
# Epoch 00083: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.3061e-04 - accuracy: 1.0000 - val_loss: 0.9462 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 84/100
#
# Epoch 00084: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.1917e-04 - accuracy: 1.0000 - val_loss: 0.9516 - val_accuracy: 0.9019 - lr: 1.0000e-04
# Epoch 85/100
#
# Epoch 00085: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.1405e-04 - accuracy: 1.0000 - val_loss: 0.9562 - val_accuracy: 0.9020 - lr: 1.0000e-04
# Epoch 86/100
#
# Epoch 00086: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.9454 - val_accuracy: 0.9010 - lr: 1.0000e-04
# Epoch 87/100
#
# Epoch 00087: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 4.2996e-04 - accuracy: 1.0000 - val_loss: 0.9448 - val_accuracy: 0.9007 - lr: 1.0000e-04
# Epoch 88/100
#
# Epoch 00088: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.8142e-04 - accuracy: 1.0000 - val_loss: 0.9505 - val_accuracy: 0.9010 - lr: 1.0000e-04
# Epoch 89/100
#
# Epoch 00089: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.4368e-04 - accuracy: 1.0000 - val_loss: 0.9579 - val_accuracy: 0.9004 - lr: 1.0000e-04
# Epoch 90/100
#
# Epoch 00090: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.2516e-04 - accuracy: 1.0000 - val_loss: 0.9629 - val_accuracy: 0.9013 - lr: 1.0000e-04
# Epoch 91/100
#
# Epoch 00091: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.1439e-04 - accuracy: 1.0000 - val_loss: 0.9656 - val_accuracy: 0.9013 - lr: 1.0000e-04
# Epoch 92/100
#
# Epoch 00092: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 1.0580e-04 - accuracy: 1.0000 - val_loss: 0.9687 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 93/100
#
# Epoch 00093: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 9.8523e-05 - accuracy: 1.0000 - val_loss: 0.9714 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 94/100
#
# Epoch 00094: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 9.4209e-05 - accuracy: 1.0000 - val_loss: 0.9750 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 95/100
#
# Epoch 00095: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 9.0273e-05 - accuracy: 1.0000 - val_loss: 0.9789 - val_accuracy: 0.9018 - lr: 1.0000e-04
# Epoch 96/100
#
# Epoch 00096: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 8.6701e-05 - accuracy: 1.0000 - val_loss: 0.9825 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 97/100
#
# Epoch 00097: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 8.3192e-05 - accuracy: 1.0000 - val_loss: 0.9861 - val_accuracy: 0.9016 - lr: 1.0000e-04
# Epoch 98/100
#
# Epoch 00098: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 8.1394e-05 - accuracy: 1.0000 - val_loss: 0.9882 - val_accuracy: 0.9014 - lr: 1.0000e-04
# Epoch 99/100
#
# Epoch 00099: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 7.9202e-05 - accuracy: 1.0000 - val_loss: 0.9873 - val_accuracy: 0.9024 - lr: 1.0000e-04
# Epoch 100/100
#
# Epoch 00100: val_accuracy did not improve from 0.90400
# 200/200 - 0s - loss: 7.5400e-05 - accuracy: 1.0000 - val_loss: 0.9944 - val_accuracy: 0.9014 - lr: 1.0000e-04

# %%
pruned_model_2.load_weights('mlp.mnist.sparse_train_2.hdf5')
print(pruned_model_2.evaluate(X_val, y_val, verbose=0))
pruned_model_2.evaluate(X_test, y_test, verbose=0)
# Out:
# [0.792011022567749, 0.9039999842643738]
# [0.86404949426651, 0.8998000025749207]

# %%
plt.plot(history_1.history['val_accuracy'], c='r')
plt.plot(history_2.history['val_accuracy'], c='g')
plt.plot(history_3.history['val_accuracy'], c='b')
